# %%
# %run "../../scripts/utility_readblt_fake.py" "fake3mu"
# Out:
# fake3mu selection *** muon_2016B: 100%|███████████████████████| 5.62k/5.62k [00:01<00:00, 5.25kit/s]
# fake3mu selection *** muon_2016C: 100%|███████████████████████| 2.44k/2.44k [00:00<00:00, 6.66kit/s]
# fake3mu selection *** muon_2016D: 100%|███████████████████████| 4.05k/4.05k [00:00<00:00, 6.67kit/s]
# fake3mu selection *** muon_2016E: 100%|███████████████████████| 3.68k/3.68k [00:00<00:00, 5.12kit/s]
# fake3mu selection *** muon_2016F: 100%|███████████████████████| 2.89k/2.89k [00:00<00:00, 6.18kit/s]
# fake3mu selection *** muon_2016G: 100%|███████████████████████| 7.93k/7.93k [00:01<00:00, 6.78kit/s]
# fake3mu selection *** muon_2016H: 100%|███████████████████████| 9.21k/9.21k [00:01<00:00, 6.39kit/s]
# fake3mu selection *** ww: 100%|█████████████████████████████████| 32.0/32.0 [00:00<00:00, 5.07kit/s]
# fake3mu selection *** wz_2l2q: 100%|██████████████████████████| 23.7k/23.7k [00:03<00:00, 6.98kit/s]
# fake3mu selection *** wz_3lnu: 100%|██████████████████████████| 13.2k/13.2k [00:01<00:00, 7.15kit/s]
# fake3mu selection *** zz_2l2nu: 100%|█████████████████████████| 2.73k/2.73k [00:00<00:00, 5.06kit/s]
# fake3mu selection *** zz_2l2q: 100%|██████████████████████████| 33.0k/33.0k [00:04<00:00, 6.65kit/s]
# fake3mu selection *** zz_4l: 100%|████████████████████████████| 80.2k/80.2k [00:11<00:00, 6.77kit/s]
# fake3mu selection *** zjets_m-50: 100%|███████████████████████| 6.95k/6.95k [00:01<00:00, 6.67kit/s]
# fake3mu selection *** zjets_m-10to50: 100%|█████████████████████| 1.00/1.00 [00:00<00:00, 1.50kit/s]
# fake3mu selection *** w3jets: 100%|█████████████████████████████| 2.00/2.00 [00:00<00:00, 2.39kit/s]
# fake3mu selection *** w4jets: 100%|█████████████████████████████| 2.00/2.00 [00:00<00:00, 2.41kit/s]
# fake3mu selection *** t_tw: 100%|███████████████████████████████| 97.0/97.0 [00:00<00:00, 6.57kit/s]
# fake3mu selection *** tbar_tw: 100%|████████████████████████████| 85.0/85.0 [00:00<00:00, 6.56kit/s]
# fake3mu selection *** w3jets: 100%|█████████████████████████████| 2.00/2.00 [00:00<00:00, 2.50kit/s]
# fake3mu selection *** w4jets: 100%|█████████████████████████████| 2.00/2.00 [00:00<00:00, 2.61kit/s]
# fake3mu selection *** ttbar_inclusive: 100%|██████████████████| 20.4k/20.4k [00:03<00:00, 6.74kit/s]

# %%
from utility_common import *
from utility_plotter import *
import ROOT
from IPython.display import clear_output
## add plotting option and load plotting parameter table
# %matplotlib inline

#%qtconsole --style monokai
plt.style.use('classic')
plt.rc("figure",facecolor="w",figsize=(6,4))
plt.rc("font",size=10)
plt.rc("savefig",dpi=300)

# %%
pickledir  =  "/home/zchen/Documents/Analysis/workplace/data/fake/fake3mu/"
#cuts = 'lepton3_iso <0.15 '
cuts = 'lepton3_pt>0'# & lepton3_iso <0.15'
Data = LoadDataframe(pickledir + "data2016").query(cuts)
MCzz = LoadDataframe(pickledir + "mcdiboson").query(cuts)
#MCzz2 = LoadDataframe(pickledir + "mczw").query(cuts)
MCdy = LoadDataframe(pickledir + "mcdy").query(cuts)
MCt  = LoadDataframe(pickledir + "mct").query(cuts)
MCtt = LoadDataframe(pickledir + "mctt").query(cuts)

# %%
pp = pd.read_csv("plotparametersfake.csv")
df_list = [ MCt,MCtt, MCdy, MCzz,  Data]
label_list = ['tW','ttbar','V+Jets', 'Diboson', 'data']
color_list = ["#a32020",  "#eb8c00", "deepskyblue", "mediumpurple", "k"]

# %%
folder = 'fake3mu'
for index, row in pp.iterrows():
    v,a,b,step,xl = row["var"], row["lower"], row["upper"], row["step"], row["xlabel"]
      
    plotter = SelectionPlotter(v,a,b,step,df_list)

    plotter.settingPlot(xl,label_list,color_list,logscale=False)
    plotter.makePlot("../../plot/{}/linear/".format(folder))
    plt.close()
    
    plotter.settingPlot(xl,label_list,color_list,logscale=True)
    plotter.makePlot("../../plot/{}/log/".format(folder))
    plt.close()
    # print out process
    print("making plots: {0}/{1}".format(index,len(pp)))
    clear_output(wait=True)
    

print('finish all making plots')
# Out:
# finish all making plots

# %%
f = 128/2880
f/(1-f)
# Out:
# 0.046511627906976744

# %% [markdown]
# # Some quick checks

# %%
for thisdf in [MCzz, MCdy, MCt, MCtt, Data]:
    n = np.sum(thisdf.eventWeight)
    nerr = np.sum(thisdf.eventWeight**2)**0.5
    print('{:.2f},{:.2f}'.format(n,nerr))
# Out:
# 653.20,6.34
# 2297.59,98.85
# 27.01,5.84
# 551.19,10.33
# 4089.00,63.95

# %%
plt.style.use('classic')
plt.rc("figure",facecolor="w",figsize=(6,4))

v,a,b,step,xl = "dilepton_mass",70,110,1,"dilepton_mass [GeV]"
plotter = SelectionPlotter(v,a,b,step,df_list)
plotter.settingPlot(xl,label_list,color_list,logscale=False)
plotter.makePlot()
plt.savefig("../../plot/dilepton_mass_2mu.png",dpi=200)
# Out:
# /home/zchen/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
v,a,b,step,xl = "lepton3_pt",0,100,2,"lepton3_pt [GeV]"
plotter = SelectionPlotter(v,a,b,step,df_list,adjust=[1,1,1,1])
plotter.settingPlot(xl,label_list,color_list)
plotter.makePlot()
plt.savefig("../../plot/lepton3_pt.png",dpi=200)
# Out:
# /home/zchen/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
plt.style.use('classic')
plt.rc("figure",facecolor="w",figsize=(6,4))

v,a,b,step,xl = "lepton3_iso",0,5,0.1,"lepton3_iso"
plotter = SelectionPlotter(v,a,b,step,df_list)
plotter.settingPlot(xl,label_list,color_list,logscale=False)
plotter.makePlot()
plt.savefig("../../plot/nMuons_2mu.png",dpi=200)
# Out:
# /home/zchen/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
plt.style.use('classic')
plt.rc("figure",facecolor="w",figsize=(6,4))

v,a,b,step,xl = "nMuons",0,10,1,"nMuons"
plotter = SelectionPlotter(v,a,b,step,df_list)
plotter.settingPlot(xl,label_list,color_list,logscale=True)
plotter.makePlot()
plt.savefig("../../plot/nMuons_3mu.png",dpi=200)
# Out:
# /home/zchen/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
